# %%
import pyperclip
import time
import pickle
import pandas as pd
import glob

import selenium
from selenium.webdriver.common.keys import Keys
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By 
from webdriver_manager.chrome import ChromeDriverManager

import bs4

# %%
d_path = r"/Users/jack/utils/chromedriver"
s = Service(d_path)
driver = webdriver.Chrome(service=s) # 현재파일과 동일한 경로일 경우 생략 가능

user_id = 'votenffl'
user_pw = 'beggars4!'

# 1. 네이버 이동
driver.get('http://naver.com')

# 2. 로그인 버튼 클릭
login_path='//*[@id="account"]/a'
elem=driver.find_element(by=By.XPATH,value=login_path)
elem.click()

time.sleep(1)

# 3. id 복사 붙여넣기
id_path='//*[@id="id"]'
elem_id = driver.find_element(by=By.XPATH,value=id_path)
elem_id.click()

pyperclip.copy('votenffl')
elem_id.send_keys(Keys.COMMAND, 'v')

time.sleep(1)

# 4. pw 복사 붙여넣기
pw_path = '//*[@id="pw"]'
elem_pw = driver.find_element(by=By.XPATH,value=pw_path)
elem_pw.click()
pyperclip.copy('beggars4!')
elem_pw.send_keys(Keys.COMMAND, 'v')
time.sleep(1)

# 5. 로그인 버튼 클릭
login_path='//*[@id="log.login"]/span'
driver.find_element(by=By.XPATH,value=login_path).click()

# %%
# search_path
_path='//*[@id="query"]'
driver.find_element(by=By.XPATH,value=_path).click()
driver.find_element(by=By.XPATH,value=_path).send_keys('네이버 광고')
time.sleep(1)
# do search
_path='//*[@id="search_btn"]/span[2]'
driver.find_element(by=By.XPATH,value=_path).click()

# click naver ad
_path='//*[@id="main_pack"]/section[1]/div/div/div[1]/div/div[2]/a/mark'
driver.find_element(by=By.XPATH,value=_path).click()

# %%
# 윈도우 이동
driver.switch_to.window(driver.window_handles[1])

# %%
# 팝업삭제
_path='//*[@id="mat-dialog-0"]/naver-login-confirm/div[2]/div/button'
driver.find_element(by=By.XPATH,value=_path).click()

# %%
_path='//*[@id="header_js"]/div/ul/li[2]/a'
driver.find_element(by=By.XPATH,value=_path).click()

# %%
# 광고시스템으로 들어가기
driver.switch_to.window(driver.window_handles[2])

# %%
# 캠페인으로 들어가기
_path='//*[@id="root"]/div/div[2]/div/div[3]/div/div[3]/table/tbody/tr[2]/td[4]/div/a'
driver.find_element(by=By.XPATH,value=_path).click()

# %%
# 광고그룹으로 들어가기
_path='//*[@id="root"]/div/div[2]/div/div[1]/div[4]/div/div[1]/div/div/div[3]/table/tbody/tr[2]/td[4]/div/a'
driver.find_element(by=By.XPATH,value=_path).click()

# %%
with open('raw_data/daily_trend/2022_11_12.pickle','rb') as f:
    _dict_=pickle.load(f)
pd.DataFrame(_dict_)
# Out:
#          패션의류    패션잡화 화장품/미용  디지털/가전 가구/인테리어   출산/육아    식품   스포츠/레저  \
# 0          잠옷     실내화     샴푸     가습기    암막커튼     물티슈  오메가3    무릎보호대
# 1  내셔널지오그래픽패딩      양말  트리트먼트    탄소매트      선반     답례품  양배추즙       핫팩
# 2         맨투맨    털슬리퍼   바디워시   로봇청소기      러그   젖병소독기   비오틴    허리보호대
# 3        남자니트   페이크삭스   탈모샴푸  가열식가습기      행거   순산양분유  절임배추     캠핑랜턴
# 4        남자팬티   어그슬리퍼   바디로션   무선청소기     디퓨저  어린이마스크  락토페린    손목보호대
# 5         원피스     크록스   마스크팩     프린터      베개   백일상대여   고구마  골프거리측정기
# 6        남성팬티  나이키운동화   클렌징폼     온풍기    매트리스  층간소음매트   과메기     캠핑의자
# 7        여성코트     운동화   수분크림   라디에이터      이불   유아마스크  밀크씨슬       침낭
# 8         후드티  14k목걸이    선크림      tv   모션데스크  포켓몬마스크  비타민d    캠핑테이블
# 9        커플잠옷      깔창     쿠션    전기히터  매트리스커버    아기이불    사과     발열조끼
#
#          생활/건강 여가/생활편의         면세점            도서
# 0        덴탈마스크      화환       면세점가방           학지사
# 1  kf94마스크새부리형    개업화분       면세점향수     나의문화유산답사기
# 2    차량용핸드폰거치대    근조화환  n224mdw020  ashgatepubco
# 3       차량용방향제    꽃바구니  n224wdw020       알에이치코리아
# 4      크리스마스트리    개업화환      titoni           집문당
# 5        싱크대수전     꽃배달    면세점만다리나덕           법문사
# 6       전자담배액상  부산요트투어         cpb           경문사
# 7         안마의자   문화상품권     다미아니귀걸이       세광음악출판사
# 8         철제선반   전국꽃배달    만다리나덕면세점          동양북스
# 9      kf94마스크    제주스냅  수려한골든콜라겐쿠션       베스트셀러순위

# %%
df=pd.read_csv('2022_11_14_main.csv',index_col=0)

# %%
"""pc 1위 
'//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[1]/div[2]/div/div/div/div/div[2]/div/div/div/div/label/div/select/option[1]'
pc 2위
'//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[1]/div[2]/div/div/div/div/div[2]/div/div/div/div/label/div/select/option[2]'
mobile 1위
'//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[1]/div[2]/div/div/div/div/div[2]/div/div/div/div/label/div/select/option[16]'
mobile 2위
'//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[1]/div[2]/div/div/div/div/div[2]/div/div/div/div/label/div/select/option[17]'"""
# Out:
# 'pc 1위 \n\'//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[1]/div[2]/div/div/div/div/div[2]/div/div/div/div/label/div/select/option[1]\'\npc 2위\n\'//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[1]/div[2]/div/div/div/div/div[2]/div/div/div/div/label/div/select/option[2]\'\nmobile 1위\n\'//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[1]/div[2]/div/div/div/div/div[2]/div/div/div/div/label/div/select/option[16]\'\nmobile 2위\n\'//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[1]/div[2]/div/div/div/div/div[2]/div/div/div/div/label/div/select/option[17]\''

# %%
temp_df = df.copy()
_iter_=len(temp_df)//100+1
"""여기부터 len(df)//100 만큼 반복한다."""
for i in range(15,_iter_+1):
    arg=list(temp_df['연관키워드'].values)[i*100:(i+1)*100]
    time.sleep(1.4)


    # 새키워드 추가
    _path='//*[@id="root"]/div/div[2]/div/div[1]/div[4]/div/div[1]/div/div/div[1]/div[1]/div[1]/div/button/span'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)
    _path= '/html/body/div[4]/div/div[1]/div/div/div[2]/div/div[2]/div/div[2]/div/div/div[1]/div/div[2]/textarea'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1.4)
    driver.find_element(by=By.XPATH,value=_path).send_keys('\n'.join(arg))
    time.sleep(1.4)

    # 키워드 추가후 저장
    _path= '/html/body/div[4]/div/div[1]/div/div/div[3]/button[1]'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1.4)

    # 확인
    _path ='/html/body/div[4]/div/div[1]/div/div/div[3]/button'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1.4)

    # 행 체크
    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[4]/div/div[1]/div/div/div[3]/table/thead/tr/th[1]/input'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1.4)

    # 입찰가 변경
    _path ='//*[@id="EditBidAmtDropdown"]/button'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1.4)

    # 입찰가 개별 변경
    _path ='//*[@id="EditBidAmtDropdown"]/div/button[2]'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1.4)

    # 평균입찰가 확인 체크
    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[1]/div[2]/div/div/div/div/div[2]/div/div/div/div/label/span[1]'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1.4)

    # PC 1위 체크
    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[1]/div[2]/div/div/div/div/div[2]/div/div/div/div/label/div/select/option[1]'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1.4)

    # 조회1
    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[1]/div[3]/form/button[1]'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1.4)
    # 조회2
    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[1]/div[3]/form/button[1]'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1.4)
    # 조회3
    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[1]/div[3]/form/button[1]'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1.4)

    # 입찰가 저장
    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[1]/div[3]/form/button[2]'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1.4)
    
    # 확인
    _path ='/html/body/div[4]/div/div[1]/div/div/div[3]/button'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1.4)
    
    
    # 다운로드
    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[2]/div[1]/div[1]/div[2]/div/button'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1.4)

    # 삭제
    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[2]/div[1]/div[1]/div[1]/div/div[2]/button'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1.4)

    # 삭제확인
    _path ='/html/body/div[4]/div/div[1]/div/div/div[3]/button[1]'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1.4)

    # 돌아가기
    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[1]/div/div[1]/table/tbody/tr/td[1]/button/span'
    driver.find_element(by=By.XPATH,value=_path).click()
# Out:
# ---------------------------------------------------------------------------
# ElementClickInterceptedException          Traceback (most recent call last)
# Cell In [19], line 31
#      29 # 행 체크
#      30 _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[4]/div/div[1]/div/div/div[3]/table/thead/tr/th[1]/input'
# ---> 31 driver.find_element(by=By.XPATH,value=_path).click()
#      32 time.sleep(1.4)
#      34 # 입찰가 변경
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/crawling/lib/python3.10/site-packages/selenium/webdriver/remote/webelement.py:88, in WebElement.click(self)
#      86 def click(self) -> None:
#      87     """Clicks the element."""
# ---> 88     self._execute(Command.CLICK_ELEMENT)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/crawling/lib/python3.10/site-packages/selenium/webdriver/remote/webelement.py:396, in WebElement._execute(self, command, params)
#     394     params = {}
#     395 params['id'] = self._id
# --> 396 return self._parent.execute(command, params)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/crawling/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:429, in WebDriver.execute(self, driver_command, params)
#     427 response = self.command_executor.execute(driver_command, params)
#     428 if response:
# --> 429     self.error_handler.check_response(response)
#     430     response['value'] = self._unwrap_value(
#     431         response.get('value', None))
#     432     return response
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/crawling/lib/python3.10/site-packages/selenium/webdriver/remote/errorhandler.py:243, in ErrorHandler.check_response(self, response)
#     241         alert_text = value['alert'].get('text')
#     242     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 243 raise exception_class(message, screen, stacktrace)
#
# ElementClickInterceptedException: Message: element click intercepted: Element <input type="checkbox"> is not clickable at point (279, 808). Other element would receive the click: <div class="modal fade show" role="dialog" tabindex="-1" style="display: block;">...</div>
#   (Session info: chrome=107.0.5304.110)
# Stacktrace:
# 0   chromedriver                        0x00000001027eaa88 chromedriver + 4123272
# 1   chromedriver                        0x0000000102776778 chromedriver + 3647352
# 2   chromedriver                        0x0000000102438ac4 chromedriver + 248516
# 3   chromedriver                        0x00000001024758a8 chromedriver + 497832
# 4   chromedriver                        0x0000000102473874 chromedriver + 489588
# 5   chromedriver                        0x00000001024714e8 chromedriver + 480488
# 6   chromedriver                        0x00000001024704dc chromedriver + 476380
# 7   chromedriver                        0x0000000102464a00 chromedriver + 428544
# 8   chromedriver                        0x0000000102464260 chromedriver + 426592
# 9   chromedriver                        0x00000001024a1020 chromedriver + 675872
# 10  chromedriver                        0x0000000102462b10 chromedriver + 420624
# 11  chromedriver                        0x0000000102463c30 chromedriver + 425008
# 12  chromedriver                        0x00000001027bcae4 chromedriver + 3934948
# 13  chromedriver                        0x00000001027bff24 chromedriver + 3948324
# 14  chromedriver                        0x00000001027c0508 chromedriver + 3949832
# 15  chromedriver                        0x00000001027c6b30 chromedriver + 3975984
# 16  chromedriver                        0x00000001027c0b24 chromedriver + 3951396
# 17  chromedriver                        0x000000010279b71c chromedriver + 3798812
# 18  chromedriver                        0x00000001027dd2f0 chromedriver + 4068080
# 19  chromedriver                        0x00000001027dd444 chromedriver + 4068420
# 20  chromedriver                        0x00000001027f1450 chromedriver + 4150352
# 21  libsystem_pthread.dylib             0x000000019869c26c _pthread_start + 148
# 22  libsystem_pthread.dylib             0x000000019869708c thread_start + 8

# %%
# Out:
# 15

# %%
paths=glob.glob('../../../../Downloads/*.xlsx')
retry_paths= []
for path in paths:
    temp=pd.read_excel(path).iloc[1:,:]
    len_not_done=len(temp[temp['입찰가']==70])
    if len_not_done > 80:
        print(path)
        retry_paths.append(path)
# Out:
# ../../../../Downloads/키워드 목록 20221114 1527 (1).xlsx
# ../../../../Downloads/키워드 목록 20221114 1540 (2).xlsx
# ../../../../Downloads/키워드 목록 20221114 1539.xlsx
# ../../../../Downloads/키워드 목록 20221114 1535.xlsx
# ../../../../Downloads/키워드 목록 20221114 1537 (1).xlsx
# ../../../../Downloads/키워드 목록 20221114 1537.xlsx
# ../../../../Downloads/키워드 목록 20221114 1534 (2).xlsx
# ../../../../Downloads/키워드 목록 20221114 1539 (1).xlsx
# ../../../../Downloads/키워드 목록 20221114 1541.xlsx
# ../../../../Downloads/키워드 목록 20221114 1531.xlsx
# ../../../../Downloads/키워드 목록 20221114 1535 (1).xlsx
# ../../../../Downloads/키워드 목록 20221114 1525 (2).xlsx
# ../../../../Downloads/키워드 목록 20221114 1528 (1).xlsx

# %%
sorted(retry_paths)
# Out:
# ['../../../../Downloads/키워드 목록 20221114 1525 (2).xlsx',
#  '../../../../Downloads/키워드 목록 20221114 1527 (1).xlsx',
#  '../../../../Downloads/키워드 목록 20221114 1528 (1).xlsx',
#  '../../../../Downloads/키워드 목록 20221114 1531.xlsx',
#  '../../../../Downloads/키워드 목록 20221114 1534 (2).xlsx',
#  '../../../../Downloads/키워드 목록 20221114 1535 (1).xlsx',
#  '../../../../Downloads/키워드 목록 20221114 1535.xlsx',
#  '../../../../Downloads/키워드 목록 20221114 1537 (1).xlsx',
#  '../../../../Downloads/키워드 목록 20221114 1537.xlsx',
#  '../../../../Downloads/키워드 목록 20221114 1539 (1).xlsx',
#  '../../../../Downloads/키워드 목록 20221114 1539.xlsx',
#  '../../../../Downloads/키워드 목록 20221114 1540 (2).xlsx',
#  '../../../../Downloads/키워드 목록 20221114 1541.xlsx']

# %%
key_words = []
for path in retry_paths:
    temp=pd.read_excel(path).iloc[1:,:]
    key_words.append(list(temp['키워드'].values))

# %%
keywords=[['트레이닝복세트', '받치다', '드라이샴푸', '글리세린', '클리너', '답례품', '구디백', '홍보물품',
       '과자세트', '홍보물', '사은품', '100일선물', '청소용품', 'GWP', '제주도기념품', '제주도소품샵',
       '우도땅콩', '어린이집생일답례품', 'TOP커피', '우디향', '출산선물', '베이비시터', '임신축하선물',
       '코엑스베이비페어', '기저귀교환대', '육아', '초점책', '혈장', '영주장날', '전자담배액상', '데이트팝',
       '새빛둥둥섬', '스페인', '어린이', '국내여행안내사', '자서전', '도서순위', '북큐레이션', '추리소설',
       '인체', '학습', '생물', '물리', '과학', '소설책', '소설추천', '한영사전', '고전소설',
       '심리학책추천', 'BOOK', '데미안줄거리', '발', '삼국지13', '신곡', '추리소설추천', '클래식공연',
       '클래식음악', '토론', '미술전시회', '한국사', '영어도서관', '스터디카페', '자기개발서', '자기계발서']]

# %%
"""여기부터 len(df)//100 만큼 반복한다."""
for arg in keywords:
    time.sleep(2)


    # 새키워드 추가
    _path='//*[@id="root"]/div/div[2]/div/div[1]/div[4]/div/div[1]/div/div/div[1]/div[1]/div[1]/div/button/span'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(2)
    _path= '/html/body/div[4]/div/div[1]/div/div/div[2]/div/div[2]/div/div[2]/div/div/div[1]/div/div[2]/textarea'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(2)
    driver.find_element(by=By.XPATH,value=_path).send_keys('\n'.join(arg))
    time.sleep(2)

    # 키워드 추가후 저장
    _path= '/html/body/div[4]/div/div[1]/div/div/div[3]/button[1]'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(2)

    # 확인
    _path ='/html/body/div[4]/div/div[1]/div/div/div[3]/button'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(2)

    # 행 체크
    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[4]/div/div[1]/div/div/div[3]/table/thead/tr/th[1]/input'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(2)

    # 입찰가 변경
    _path ='//*[@id="EditBidAmtDropdown"]/button'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(2)

    # 입찰가 개별 변경
    _path ='//*[@id="EditBidAmtDropdown"]/div/button[2]'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(2)

    # 평균입찰가 확인 체크
    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[1]/div[2]/div/div/div/div/div[2]/div/div/div/div/label/span[1]'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(2)

    # 모바일 1위 체크
    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[1]/div[2]/div/div/div/div/div[2]/div/div/div/div/label/div/select/option[1]'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(2)

    # 조회
    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[1]/div[3]/form/button[1]'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(2)

    # 입찰가 저장
    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[1]/div[3]/form/button[2]'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(2)
    # 확인
    _path ='/html/body/div[4]/div/div[1]/div/div/div[3]/button'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(2)
    
    # 다운로드
    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[2]/div[1]/div[1]/div[2]/div/button'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(2)

    # 삭제
    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[2]/div[1]/div[1]/div[1]/div/div[2]/button'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(2)

    # 삭제확인
    _path ='/html/body/div[4]/div/div[1]/div/div/div[3]/button[1]'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(2)

    # 돌아가기
    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[1]/div/div[1]/table/tbody/tr/td[1]/button/span'
    driver.find_element(by=By.XPATH,value=_path).click()
# Out:
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# Cell In [12], line 38
#      36 # 입찰가 개별 변경
#      37 _path ='//*[@id="EditBidAmtDropdown"]/div/button[2]'
# ---> 38 driver.find_element(by=By.XPATH,value=_path).click()
#      39 time.sleep(2)
#      41 # 평균입찰가 확인 체크
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/crawling/lib/python3.10/site-packages/selenium/webdriver/remote/webelement.py:88, in WebElement.click(self)
#      86 def click(self) -> None:
#      87     """Clicks the element."""
# ---> 88     self._execute(Command.CLICK_ELEMENT)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/crawling/lib/python3.10/site-packages/selenium/webdriver/remote/webelement.py:396, in WebElement._execute(self, command, params)
#     394     params = {}
#     395 params['id'] = self._id
# --> 396 return self._parent.execute(command, params)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/crawling/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:429, in WebDriver.execute(self, driver_command, params)
#     427 response = self.command_executor.execute(driver_command, params)
#     428 if response:
# --> 429     self.error_handler.check_response(response)
#     430     response['value'] = self._unwrap_value(
#     431         response.get('value', None))
#     432     return response
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/crawling/lib/python3.10/site-packages/selenium/webdriver/remote/errorhandler.py:243, in ErrorHandler.check_response(self, response)
#     241         alert_text = value['alert'].get('text')
#     242     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 243 raise exception_class(message, screen, stacktrace)
#
# ElementNotInteractableException: Message: element not interactable
#   (Session info: chrome=107.0.5304.110)
# Stacktrace:
# 0   chromedriver                        0x0000000100fb6a88 chromedriver + 4123272
# 1   chromedriver                        0x0000000100f42778 chromedriver + 3647352
# 2   chromedriver                        0x0000000100c04944 chromedriver + 248132
# 3   chromedriver                        0x0000000100c3bfd0 chromedriver + 475088
# 4   chromedriver                        0x0000000100c30a00 chromedriver + 428544
# 5   chromedriver                        0x0000000100c30260 chromedriver + 426592
# 6   chromedriver                        0x0000000100c6d020 chromedriver + 675872
# 7   chromedriver                        0x0000000100c2eb10 chromedriver + 420624
# 8   chromedriver                        0x0000000100c2fc30 chromedriver + 425008
# 9   chromedriver                        0x0000000100f88ae4 chromedriver + 3934948
# 10  chromedriver                        0x0000000100f8bf24 chromedriver + 3948324
# 11  chromedriver                        0x0000000100f8c508 chromedriver + 3949832
# 12  chromedriver                        0x0000000100f92b30 chromedriver + 3975984
# 13  chromedriver                        0x0000000100f8cb24 chromedriver + 3951396
# 14  chromedriver                        0x0000000100f6771c chromedriver + 3798812
# 15  chromedriver                        0x0000000100fa92f0 chromedriver + 4068080
# 16  chromedriver                        0x0000000100fa9444 chromedriver + 4068420
# 17  chromedriver                        0x0000000100fbd450 chromedriver + 4150352
# 18  libsystem_pthread.dylib             0x000000019869c26c _pthread_start + 148
# 19  libsystem_pthread.dylib             0x000000019869708c thread_start + 8

# %%
paths=glob.glob('../../../../Downloads/*.xlsx')
retry_paths= []
for path in paths:
    temp=pd.read_excel(path).iloc[1:,:]
    len_not_done=len(temp[temp['입찰가']==70])
    if len_not_done > 80:
        print(path)
        retry_paths.append(path)

# %%
../../../../Downloads/키워드 목록 20221114 1441.xlsx
../../../../Downloads/키워드 목록 20221114 1453 (1).xlsx
../../../../Downloads/키워드 목록 20221114 1448 (1).xlsx
../../../../Downloads/키워드 목록 20221114 1443 (1).xlsx
../../../../Downloads/키워드 목록 20221114 1447 (1).xlsx
../../../../Downloads/키워드 목록 20221114 1446 (1).xlsx
../../../../Downloads/키워드 목록 20221114 1445.xlsx
../../../../Downloads/키워드 목록 20221114 1438.xlsx
