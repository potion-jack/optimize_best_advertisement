# %%
import pyperclip
import time
import pickle
import pandas as pd
import glob

import selenium
from selenium.webdriver.common.keys import Keys
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By 
from webdriver_manager.chrome import ChromeDriverManager

import bs4

# %%
from _private_ import naver_id,naver_pw
d_path = r"/Users/jack/utils/chromedriver"
s = Service(d_path)
driver = webdriver.Chrome(service=s) # 현재파일과 동일한 경로일 경우 생략 가능

user_id = naver_id
user_pw = naver_pw

# 1. 네이버 이동
driver.get('http://naver.com')

# 2. 로그인 버튼 클릭
login_path='//*[@id="account"]/a'
elem=driver.find_element(by=By.XPATH,value=login_path)
elem.click()

time.sleep(1)

# 3. id 복사 붙여넣기
id_path='//*[@id="id"]'
elem_id = driver.find_element(by=By.XPATH,value=id_path)
elem_id.click()

pyperclip.copy(user_pw)
elem_id.send_keys(Keys.COMMAND, 'v')

time.sleep(1)

# 4. pw 복사 붙여넣기
pw_path = '//*[@id="pw"]'
elem_pw = driver.find_element(by=By.XPATH,value=pw_path)
elem_pw.click()
pyperclip.copy(user_id)
elem_pw.send_keys(Keys.COMMAND, 'v')
time.sleep(1)

# 5. 로그인 버튼 클릭
login_path='//*[@id="log.login"]/span'
driver.find_element(by=By.XPATH,value=login_path).click()

# %%
# search_path
_path='//*[@id="query"]'
driver.find_element(by=By.XPATH,value=_path).click()
driver.find_element(by=By.XPATH,value=_path).send_keys('네이버 광고')
time.sleep(1)
# do search
_path='//*[@id="search_btn"]/span[2]'
driver.find_element(by=By.XPATH,value=_path).click()

# click naver ad
_path='//*[@id="main_pack"]/section[1]/div/div/div[1]/div/div[2]/a/mark'
driver.find_element(by=By.XPATH,value=_path).click()

# %%
# 윈도우 이동
driver.switch_to.window(driver.window_handles[1])

# %%
# 팝업삭제
_path='//*[@id="mat-dialog-0"]/naver-login-confirm/div[2]/div/button'
driver.find_element(by=By.XPATH,value=_path).click()

# %%
_path='//*[@id="header_js"]/div/ul/li[2]/a'
driver.find_element(by=By.XPATH,value=_path).click()

# %%
# 광고시스템으로 들어가기
driver.switch_to.window(driver.window_handles[2])

# %%
# 캠페인으로 들어가기
_path='//*[@id="root"]/div/div[2]/div/div[3]/div/div[3]/table/tbody/tr[2]/td[4]/div/a'
driver.find_element(by=By.XPATH,value=_path).click()

# %%
# 광고그룹으로 들어가기
_path='//*[@id="root"]/div/div[2]/div/div[1]/div[4]/div/div[1]/div/div/div[3]/table/tbody/tr[2]/td[4]/div/a'
driver.find_element(by=By.XPATH,value=_path).click()

# %%
df=pd.read_csv('main_data.csv')

# %%
from tqdm import tqdm

# %%
"""
pc_1
'//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[1]/div[2]/div/div/div/div/div[2]/div/div/div/div/label/div/select/option[1]'
pc_2
'//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[1]/div[2]/div/div/div/div/div[2]/div/div/div/div/label/div/select/option[2]'
mobile_1
'//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[1]/div[2]/div/div/div/div/div[2]/div/div/div/div/label/div/select/option[16]'
mobile_2
'//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[1]/div[2]/div/div/div/div/div[2]/div/div/div/div/label/div/select/option[17]'
"""

# %%
temp_df = df.copy()
_iter_=len(temp_df)//100
"""여기부터 len(df)//100 만큼 반복한다."""
for i in tqdm(range(_iter_+1)):
    arg=list(temp_df['연관키워드'].values)[i*100:(i+1)*100]
    time.sleep(1)


    # 새키워드 추가
    _path='//*[@id="root"]/div/div[2]/div/div[1]/div[4]/div/div[1]/div/div/div[1]/div[1]/div[1]/div/button/span'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)
    _path= '/html/body/div[4]/div/div[1]/div/div/div[2]/div/div[2]/div/div[2]/div/div/div[1]/div/div[2]/textarea'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)
    driver.find_element(by=By.XPATH,value=_path).send_keys('\n'.join(arg))
    time.sleep(1)

    # 키워드 추가후 저장
    _path= '/html/body/div[4]/div/div[1]/div/div/div[3]/button[1]'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)

    # 확인
    _path ='/html/body/div[4]/div/div[1]/div/div/div[3]/button'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)

    # 행 체크
    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[4]/div/div[1]/div/div/div[3]/table/thead/tr/th[1]/input'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)

    # 입찰가 변경
    _path ='//*[@id="EditBidAmtDropdown"]/button'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)

    # 입찰가 개별 변경
    _path ='//*[@id="EditBidAmtDropdown"]/div/button[2]'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)

    # 평균입찰가 확인 체크
    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[1]/div[2]/div/div/div/div/div[2]/div/div/div/div/label/span[1]'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)
    
    ##
    # pc_1위 체크
    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[1]/div[2]/div/div/div/div/div[2]/div/div/div/div/label/div/select/option[1]'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)

    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[2]/div[3]/table/thead/tr/th[1]/input'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)
    
    # 조회1
    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[1]/div[3]/form/button[1]'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)

    # 입찰가 저장
    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[1]/div[3]/form/button[2]'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)
    
    # 확인
    _path ='/html/body/div[4]/div/div[1]/div/div/div[3]/button'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)
    
    # 다운로드
    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[2]/div[1]/div[1]/div[2]/div/button'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)
    ##
    
    ##
    # pc_2
    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[1]/div[2]/div/div/div/div/div[2]/div/div/div/div/label/div/select/option[2]'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)
    
    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[2]/div[3]/table/thead/tr/th[1]/input'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)
    
    # 조회1
    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[1]/div[3]/form/button[1]'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)

    # 입찰가 저장
    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[1]/div[3]/form/button[2]'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)
    
    # 확인
    _path ='/html/body/div[4]/div/div[1]/div/div/div[3]/button'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)
    
    # 다운로드
    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[2]/div[1]/div[1]/div[2]/div/button'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)
    
    ##
    ##
    # mobile_1
    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[1]/div[2]/div/div/div/div/div[2]/div/div/div/div/label/div/select/option[16]'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)

    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[2]/div[3]/table/thead/tr/th[1]/input'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)
    
    # 조회1
    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[1]/div[3]/form/button[1]'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)

    # 입찰가 저장
    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[1]/div[3]/form/button[2]'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)
    
    # 확인
    _path ='/html/body/div[4]/div/div[1]/div/div/div[3]/button'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)
    
    # 다운로드
    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[2]/div[1]/div[1]/div[2]/div/button'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)
    
    ## 
    ##
    # mobile_2
    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[1]/div[2]/div/div/div/div/div[2]/div/div/div/div/label/div/select/option[17]'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)

    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[2]/div[3]/table/thead/tr/th[1]/input'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)
    
    # 조회1
    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[1]/div[3]/form/button[1]'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)

    # 입찰가 저장
    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[1]/div[3]/form/button[2]'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)
    
    # 확인
    _path ='/html/body/div[4]/div/div[1]/div/div/div[3]/button'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)
    
    # 다운로드
    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[2]/div[1]/div[1]/div[2]/div/button'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)
    
    ## 
    # 삭제
    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[2]/div[1]/div[1]/div[1]/div/div[2]/button'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)

    # 삭제확인
    _path ='/html/body/div[4]/div/div[1]/div/div/div[3]/button[1]'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)

    # 돌아가기
    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[1]/div/div[1]/table/tbody/tr/td[1]/button/span'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)

# %%
temp_df = df.copy()
_iter_=len(temp_df)//100
"""여기부터 len(df)//100 만큼 반복한다."""
for i in tqdm(range(34,_iter_+1)):
    arg=list(temp_df['연관키워드'].values)[i*100:(i+1)*100]
    time.sleep(1)


    # 새키워드 추가
    _path='//*[@id="root"]/div/div[2]/div/div[1]/div[4]/div/div[1]/div/div/div[1]/div[1]/div[1]/div/button/span'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)
    _path= '/html/body/div[4]/div/div[1]/div/div/div[2]/div/div[2]/div/div[2]/div/div/div[1]/div/div[2]/textarea'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)
    driver.find_element(by=By.XPATH,value=_path).send_keys('\n'.join(arg))
    time.sleep(1)

    # 키워드 추가후 저장
    _path= '/html/body/div[4]/div/div[1]/div/div/div[3]/button[1]'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)

    # 확인
    _path ='/html/body/div[4]/div/div[1]/div/div/div[3]/button'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)

    # 행 체크
    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[4]/div/div[1]/div/div/div[3]/table/thead/tr/th[1]/input'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)

    # 입찰가 변경
    _path ='//*[@id="EditBidAmtDropdown"]/button'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)

    # 입찰가 개별 변경
    _path ='//*[@id="EditBidAmtDropdown"]/div/button[2]'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)

    # 평균입찰가 확인 체크
    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[1]/div[2]/div/div/div/div/div[2]/div/div/div/div/label/span[1]'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)
    
    ##
    # pc_1위 체크
    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[1]/div[2]/div/div/div/div/div[2]/div/div/div/div/label/div/select/option[1]'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)

    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[2]/div[3]/table/thead/tr/th[1]/input'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)
    
    # 조회1
    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[1]/div[3]/form/button[1]'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)

    # 입찰가 저장
    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[1]/div[3]/form/button[2]'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)
    
    # 확인
    _path ='/html/body/div[4]/div/div[1]/div/div/div[3]/button'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)
    
    # 다운로드
    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[2]/div[1]/div[1]/div[2]/div/button'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)
    ##
    
    ##
    # pc_2
    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[1]/div[2]/div/div/div/div/div[2]/div/div/div/div/label/div/select/option[2]'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)
    
    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[2]/div[3]/table/thead/tr/th[1]/input'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)
    
    # 조회1
    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[1]/div[3]/form/button[1]'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)

    # 입찰가 저장
    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[1]/div[3]/form/button[2]'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)
    
    # 확인
    _path ='/html/body/div[4]/div/div[1]/div/div/div[3]/button'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)
    
    # 다운로드
    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[2]/div[1]/div[1]/div[2]/div/button'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)
    
    ##
    ##
    # mobile_1
    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[1]/div[2]/div/div/div/div/div[2]/div/div/div/div/label/div/select/option[16]'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)

    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[2]/div[3]/table/thead/tr/th[1]/input'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)
    
    # 조회1
    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[1]/div[3]/form/button[1]'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)

    # 입찰가 저장
    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[1]/div[3]/form/button[2]'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)
    
    # 확인
    _path ='/html/body/div[4]/div/div[1]/div/div/div[3]/button'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)
    
    # 다운로드
    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[2]/div[1]/div[1]/div[2]/div/button'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)
    
    ## 
    ##
    # mobile_2
    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[1]/div[2]/div/div/div/div/div[2]/div/div/div/div/label/div/select/option[17]'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)

    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[2]/div[3]/table/thead/tr/th[1]/input'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)
    
    # 조회1
    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[1]/div[3]/form/button[1]'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)

    # 입찰가 저장
    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[1]/div[3]/form/button[2]'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)
    
    # 확인
    _path ='/html/body/div[4]/div/div[1]/div/div/div[3]/button'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)
    
    # 다운로드
    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[2]/div[1]/div[1]/div[2]/div/button'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)
    
    ## 
    # 삭제
    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[2]/div[2]/div[1]/div[1]/div[1]/div/div[2]/button'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)

    # 삭제확인
    _path ='/html/body/div[4]/div/div[1]/div/div/div[3]/button[1]'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)

    # 돌아가기
    _path ='//*[@id="root"]/div/div[2]/div/div[1]/div[1]/div/div[1]/table/tbody/tr/td[1]/button/span'
    driver.find_element(by=By.XPATH,value=_path).click()
    time.sleep(1)
