# %% [markdown]
# # modeling trial

# %%
import pandas as pd
df=pd.read_csv('df_final_serious.csv',index_col=0)
# df.set_index('연관키워드',inplace=True)

# %%
df['입찰가_m1']
# Out:
#          연관키워드  type  월간검색수_PC  월간검색수_모바일  월평균클릭수_PC  월평균클릭수_모바일  월평균클릭률_PC  \
# 0           잠옷  패션의류   15600.0   128600.0      268.1      2951.4       1.78
# 1         커플잠옷  패션의류    6320.0    57800.0      166.0      2431.6       2.74
# 2          홈웨어  패션의류    3570.0    22400.0       67.3       484.8       1.96
# 3        잠옷브랜드  패션의류    1230.0     6080.0       24.9       203.7       2.07
# 4         수면잠옷  패션의류    7740.0    74800.0       42.4      1237.0       0.57
# ...        ...   ...       ...        ...        ...         ...        ...
# 4329    푸에르토리코    도서    8550.0    39200.0        0.3         1.0       0.01
# 4330      풍선아트    도서    1170.0     5100.0        7.5        46.3       0.65
# 4331      비밀의집    도서    7730.0    30000.0        0.0         1.7       0.00
# 4332    피지컬컴퓨팅    도서    1360.0      990.0        0.6         0.0       0.05
# 4333  아버지의해방일지    도서    7350.0    26400.0       14.3        67.2       0.21
#
# ...

# %%
df.iloc[:,-4:]
# Out:
#       입찰가_m1  입찰가_m2  입찰가_p1  입찰가_p2
# 0     1750.0  1270.0  1990.0  1470.0
# 1     1730.0  1450.0  1680.0  1430.0
# 2     1620.0  1520.0  1690.0  1370.0
# 3     1210.0   930.0  1110.0   950.0
# 4     1730.0  1100.0  1090.0   900.0
# ...      ...     ...     ...     ...
# 4329   930.0   490.0  1070.0   390.0
# 4330  1670.0  1140.0  1970.0  1160.0
# 4331   610.0   220.0   290.0   170.0
# 4332  2040.0  1450.0  2520.0  1760.0
# 4333   600.0   420.0   770.0   600.0
#
# [4334 rows x 4 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rc('font',family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False
import scipy.stats as stats
for col in df.iloc[:,-4:].columns:
    qq = stats.probplot(np.array(df[col]), plot=plt)
    plt.title(col,fontsize=15)
    plt.show()
    print("Skewness: {:.3f}".format(df[col].skew()))
# Out:
# Skewness: 8.808
# Skewness: 9.899
# Skewness: 6.194
# Skewness: 5.501

# %%
# data=pd.concat([df.drop(columns=['type']).iloc[:,:-4],
#                 pd.get_dummies(df['type'])],axis=1)
# target = df.iloc[:,-4:]

# %%
# data
# Out:
#           월간검색수_PC  월간검색수_모바일  월평균클릭수_PC  월평균클릭수_모바일  월평균클릭률_PC  월평균클릭률_모바일  \
# 연관키워드
# 잠옷         15600.0   128600.0      268.1      2951.4       1.78        2.50
# 커플잠옷        6320.0    57800.0      166.0      2431.6       2.74        4.49
# 홈웨어         3570.0    22400.0       67.3       484.8       1.96        2.34
# 잠옷브랜드       1230.0     6080.0       24.9       203.7       2.07        3.59
# 수면잠옷        7740.0    74800.0       42.4      1237.0       0.57        1.77
# ...            ...        ...        ...         ...        ...         ...
# 푸에르토리코      8550.0    39200.0        0.3         1.0       0.01        0.01
# 풍선아트        1170.0     5100.0        7.5        46.3       0.65        0.98
# 비밀의집        7730.0    30000.0        0.0         1.7       0.00        0.01
# 피지컬컴퓨팅      1360.0      990.0        0.6         0.0       0.05        0.00
# 아버지의해방일지    7350.0    26400.0       14.3        67.2       0.21        0.28
#
# ...
